# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
plt.style.use('seaborn-colorblind')
sns.set_style('darkgrid')

# %%
# Read pandas dataframe from the csv we created
df = pd.read_csv("./exome_mapping_metrics.txt", header=None, engine='python')
df
# Out:
#                                    0             1             2   \
# 0               Numero total Lecturas  4.118331e+07  3.213461e+07
# 1                % Lecturas alineadas  9.996290e-01  9.997040e-01
# 2  % Lecturas apareadas correctamente  9.906920e-01  9.905480e-01
# 3                    PF_HQ_ERROR_RATE  1.206000e-03  1.320000e-03
#
#              3             4             5             6             7   \
# 0  3.597531e+07  3.091008e+07  3.144764e+07  3.484558e+07  3.297658e+07
# 1  9.989060e-01  9.988690e-01  9.989230e-01  9.985130e-01  9.996860e-01
# 2  9.925750e-01  9.920800e-01  9.937930e-01  9.921030e-01  9.906730e-01
# 3  8.991000e-03  9.582000e-03  7.592000e-03  9.264000e-03  1.328000e-03
#
#              8             9       ...                 21            22  \
# 0  4.444827e+07  3.412086e+07      ...       3.192340e+07  4.021241e+07
# 1  9.989680e-01  9.997380e-01      ...       9.997250e-01  9.988750e-01
# ...

# %%
testing = df.transpose()
testing.columns = testing.iloc[0]
good = testing.reindex(testing.index.drop(0))
good.loc[:,'% Lecturas alineadas'] = good['% Lecturas alineadas']*100
good.loc[:,'% Lecturas apareadas correctamente'] = good['% Lecturas apareadas correctamente']*100
good.loc[:,'PF_HQ_ERROR_RATE'] = good['PF_HQ_ERROR_RATE']*100
good.loc[:,'Numero total Lecturas'] = good['Numero total Lecturas']
good
# Out:
# 0  Numero total Lecturas % Lecturas alineadas  \
# 1            4.11833e+07              99.9629
# 2            3.21346e+07              99.9704
# 3            3.59753e+07              99.8906
# 4            3.09101e+07              99.8869
# 5            3.14476e+07              99.8923
# 6            3.48456e+07              99.8513
# 7            3.29766e+07              99.9686
# 8            4.44483e+07              99.8968
# 9            3.41209e+07              99.9738
# 10           4.38067e+07              99.8569
# 11           3.89201e+07              99.8854
# 12           4.58653e+07              99.8245
# 13           3.49589e+07              99.8533
# 14           3.14733e+07              99.9716
# 15           4.07726e+07              99.8253
# 16           3.16094e+07              99.9722
# 17           3.59222e+07              99.9733
# 18             3.079e+07              99.9729
# 19           3.79141e+07              99.8411
# ...

# %%
plt.figure(figsize=(15, 10))

sns.boxplot(data=good)
plt.title(" ", fontsize=20)
plt.xticks(rotation=50)
plt.autoscale()
plt.show()

# %%
trs = good.transpose()

# %%
trs.mean(axis=1)
# Out:
# 0
# Numero total Lecturas                 3.658070e+07
# % Lecturas alineadas                  9.991410e+01
# % Lecturas apareadas correctamente    9.917490e+01
# PF_HQ_ERROR_RATE                      5.676667e-01
# dtype: float64

# %%
trs.std(axis=1)
# Out:
# 0
# Numero total Lecturas                 4.822611e+06
# % Lecturas alineadas                  5.430451e-02
# % Lecturas apareadas correctamente    1.594411e-01
# PF_HQ_ERROR_RATE                      4.050840e-01
# dtype: float64

# %%
trs
# Out:
#                                               1            2            3  \
# 0
# Numero total Lecturas               4.11833e+07  3.21346e+07  3.59753e+07
# % Lecturas alineadas                    99.9629      99.9704      99.8906
# % Lecturas apareadas correctamente      99.0692      99.0548      99.2575
#
#                                               4            5            6  \
# 0
# Numero total Lecturas               3.09101e+07  3.14476e+07  3.48456e+07
# % Lecturas alineadas                    99.8869      99.8923      99.8513
# % Lecturas apareadas correctamente       99.208      99.3793      99.2103
#
#                                               7            8            9  \
# 0
# Numero total Lecturas               3.29766e+07  4.44483e+07  3.41209e+07
# % Lecturas alineadas                    99.9686      99.8968      99.9738
# % Lecturas apareadas correctamente      99.0673      99.4616      99.1157
#
# ...
