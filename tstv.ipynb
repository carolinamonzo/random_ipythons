# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
plt.style.use('seaborn-colorblind')
sns.set_style('darkgrid')

# %%
# Read pandas dataframe from the csv we created
df = pd.read_csv("./tstv_all.txt", header=None, engine='python')
# Get basic statistics (mean, std, min, 25%, 50%, 75%, max)
df_summary = df.describe().transpose()
df_summary
# Out:
#     count    mean       std    min      25%     50%      75%    max
# 1     2.0  2.3380  0.090510  2.274  2.30600  2.3380  2.37000  2.402
# 2     2.0  2.3455  0.060104  2.303  2.32425  2.3455  2.36675  2.388
# 3     2.0  2.3305  0.086974  2.269  2.29975  2.3305  2.36125  2.392
# 4     2.0  2.2930  0.033941  2.269  2.28100  2.2930  2.30500  2.317
# 5     2.0  2.3770  0.148492  2.272  2.32450  2.3770  2.42950  2.482
# 6     2.0  2.3505  0.115258  2.269  2.30975  2.3505  2.39125  2.432
# 7     2.0  2.3260  0.070711  2.276  2.30100  2.3260  2.35100  2.376
# 8     2.0  2.3210  0.080610  2.264  2.29250  2.3210  2.34950  2.378
# 9     2.0  2.3315  0.079903  2.275  2.30325  2.3315  2.35975  2.388
# 10    2.0  2.2895  0.033234  2.266  2.27775  2.2895  2.30125  2.313
# 11    2.0  2.3140  0.043841  2.283  2.29850  2.3140  2.32950  2.345
# 12    2.0  2.3680  0.124451  2.280  2.32400  2.3680  2.41200  2.456
# 13    2.0  2.3315  0.084146  2.272  2.30175  2.3315  2.36125  2.391
# ...

# %%
#df.transpose().rename(columns=df.iloc[0])
testing = df.transpose()
testing.columns = testing.iloc[0]
good = testing.reindex(testing.index.drop(0))
good
# Out:
# 0   Exome DeepSeq
# 1   2.274   2.402
# 2   2.303   2.388
# 3   2.269   2.392
# 4   2.269   2.317
# 5   2.272   2.482
# 6   2.269   2.432
# 7   2.276   2.376
# 8   2.264   2.378
# 9   2.275   2.388
# 10  2.266   2.313
# 11  2.283   2.345
# 12   2.28   2.456
# 13  2.272   2.391
# 14   1.88   2.352
# 15  1.873   2.378
# 16  1.962   2.367
# 17  1.929   2.437
# 18  1.798   2.359
# 19  1.868   2.334
# 20  1.769   2.438
# 21  1.751   2.417
# 22  1.801   2.404
# 23  1.779   2.374
# 24  1.801   2.403
# 25  1.827   2.376
# 26  1.847   2.319
# 27  1.808   2.349
# 28  1.891    2.57
# 29  1.777   2.367
# 30  1.755   2.471
# 31  1.657   2.355
# 32  1.822   2.318
# 33  1.846   2.437
# 34  1.738   2.389
# 35  1.921     NaN
# 36  1.855     NaN
# 37  1.756     NaN
# 38  1.804     NaN
# 39  1.751     NaN
# 40  1.812     NaN
# 41  1.853     NaN
# 42  1.935     NaN

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)

sns.violinplot(data=good[["Exome", "DeepSeq"]])
plt.title("Transitions/Transversions\n", fontsize=20)
plt.xticks(fontsize=14)

ax.set_xlabel('Sequencing Technique', fontsize=16)
ax.set_ylabel('Ts/Tv ratio', fontsize=16)

plt.autoscale()
plt.show()
