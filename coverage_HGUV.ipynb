# %% [markdown]
# ## Plot coverage regions of interest HGUV
#
# Prepared per base depth files, documentation: https://docs.google.com/document/d/1GeXF5oqFV3XYbwfBYnEJ6E3xbnLZsVvy-jaqQVMng7I/edit#heading=h.l2rsr7sstwjw

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
plt.style.use('seaborn-colorblind')
sns.set_style('darkgrid')

# %%
df = pd.read_csv("/home/ugdg/workspace/coverage_HGUV/pasted_coverages.tsv", sep="\t")
df
# Out:
#        chr  position  31292  31282  31307  31284  31279  31317  31316  31299  \
# 0        1  63063148     33     25     25     30     30     39     24     34
# 1        1  63063149     35     25     25     30     31     42     24     35
# 2        1  63063150     35     25     25     30     31     42     24     35
# 3        1  63063151     35     25     24     30     31     41     24     35
# 4        1  63063152     35     25     24     30     31     41     24     35
# 5        1  63063153     35     25     24     30     31     41     24     35
# 6        1  63063154     35     25     24     30     31     41     24     35
# 7        1  63063155     41     29     25     36     38     47     26     43
# 8        1  63063156     42     29     27     36     40     47     26     43
# 9        1  63063157     42     29     27     36     40     47     26     43
# 10       1  63063158     42     29     27     36     40     47     26     44
# ...

# %%
df["position"] = df["chr"].map(str) + "-" + df["position"].map(str)

# %%
ab = df.head(50)
#ab
# Out:
#    chr    position  31292  31282  31307  31284  31279  31317  31316  31299  \
# 0    1  1-63063148     33     25     25     30     30     39     24     34
# 1    1  1-63063149     35     25     25     30     31     42     24     35
# 2    1  1-63063150     35     25     25     30     31     42     24     35
#
#    31300  31318  31291  31290  31278  31315  31298  31306  31
# 0     25     30     35     41     33     27     26     32  18
# 1     25     31     35     41     33     28     27     33  19
# 2     25     31     35     41     33     28     27     33  19

# %%
plt.figure()
#plt.plot(ab["position"], ab["31292"], ab["31282"], ab["31307"], ab["31284"], ab["31279"], 
 #        ab["31317"], ab["31316"], ab["31299"]) # We are plotting X vs Y

for n in [ab["31292"], ab["31282"], ab["31307"], ab["31284"], ab["31279"],ab["31317"], ab["31316"], ab["31299"], 
          ab["31300"], ab["31318"], ab["31291"], ab["31290"], ab["31278"], ab["31315"], ab["31298"], ab["31306"]]:
    plt.plot(ab["position"], n, label=n)
plt.title("Coverage ANGPTL3")
plt.xticks(rotation=90)

plt.show()

# %%
ab = df.loc[df['chr'].map(str) == '1']
plt.figure()
for n in [ab["31292"], ab["31282"], ab["31307"], ab["31284"], ab["31279"],ab["31317"], ab["31316"], ab["31299"], 
          ab["31300"], ab["31318"], ab["31291"], ab["31290"], ab["31278"], ab["31315"], ab["31298"], ab["31306"]]:
    plt.plot(ab["position"], n, label=n)
plt.title("Coverage ANGPTL3")
plt.xticks(rotation=90)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-26b3a92eaed7> in <module>()
#       7 plt.xticks(rotation=90)
#       8
# ----> 9 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     296             publish_display_data(data=obj, metadata=metadata, **kwargs)
# ...

# %%
ab = df.loc[df['chr'].map(str) == '1']
ab["mean"] = ab.loc[:, ["31292", "31282", "31307", "31284", "31279", "31317", "31316", "31299", "31300", "31318", 
                    "31291", "31290", "31278", "31315", "31298", "31306"]].mean(axis=1)
# Out:
# /home/ugdg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure()
plt.plot(ab["position"], ab["mean"])
plt.title("Coverage ANGPTL3")
plt.xticks(rotation=90)
plt.show()

# %%
apoa = df.loc[df['chr'].map(str) == '11']
apoa.head()
# Out:
#        chr      position  31292  31282  31307  31284  31279  31317  31316  \
# 26164   11  11-116660079      0      1      2      0      0      1      2
# 26165   11  11-116660080      0      1      2      0      0      1      2
# 26166   11  11-116660081      0      1      2      0      0      1      2
# 26167   11  11-116660082      0      1      2      0      0      1      2
# 26168   11  11-116660083      0      1      2      0      0      1      2
#
#        31299  31300  31318  31291  31290  31278  31315  31298  31306  31
# 26164      1      3      0      0      0      0      0      0      0   0
# 26165      1      3      0      0      0      0      0      0      0   0
# 26166      1      3      0      0      0      0      0      0      0   0
# 26167      1      3      0      0      0      0      0      0      0   0
# 26168      1      3      0      0      0      0      0      0      0   0

# %%
plt.figure()
apoa = df.loc[df['chr'].map(str) == '11']
apoa["mean"] = apoa.loc[:, ["31292", "31282", "31307", "31284", "31279", "31317", "31316", "31299", "31300", "31318", 
                    "31291", "31290", "31278", "31315", "31298", "31306"]].mean(axis=1)
plt.plot(apoa["position"], apoa["mean"])
plt.title("Coverage APOA5")
plt.xticks(rotation=90)
plt.show()
# Out:
# /home/ugdg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
lrp6 = df.loc[df['chr'].map(str) == '12']
lrp6["mean"] = lrp6.loc[:, ["31292", "31282", "31307", "31284", "31279", "31317", "31316", "31299", "31300", "31318", 
                    "31291", "31290", "31278", "31315", "31298", "31306"]].mean(axis=1)
lrp6
# Out:
# /home/ugdg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        chr     position  31292  31282  31307  31284  31279  31317  31316  \
# 28173   12  12-12268949      0      0      0      1      0      0      0
# 28174   12  12-12268950      0      0      0      1      0      0      0
# 28175   12  12-12268951      0      0      0      1      0      0      0
# 28176   12  12-12268952      0      0      0      1      0      0      0
# 28177   12  12-12268953      0      0      0      1      0      0      0
# 28178   12  12-12268954      0      0      0      1      0      0      0
# ...

# %%
plt.figure()
lrp6 = df.loc[df['chr'].map(str) == '12']
lrp6["mean"] = lrp6.loc[:, ["31292", "31282", "31307", "31284", "31279", "31317", "31316", "31299", "31300", "31318", 
                    "31291", "31290", "31278", "31315", "31298", "31306"]].mean(axis=1)
plt.plot(lrp6["position"], lrp6["mean"])
plt.title("Coverage LRP6")
plt.xticks(rotation=90)
plt.show()
# Out:
# /home/ugdg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
plt.figure()
sec23a = df.loc[df['chr'].map(str) == '14']
sec23a["mean"] = sec23a.loc[:, ["31292", "31282", "31307", "31284", "31279", "31317", "31316", "31299", "31300", "31318", 
                    "31291", "31290", "31278", "31315", "31298", "31306"]].mean(axis=1)
plt.plot(sec23a["position"], sec23a["mean"])
plt.title("Coverage SEC23A")
plt.xticks(rotation=90)
plt.show()
# Out:
# /home/ugdg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
plt.figure()
apob = df.loc[df['chr'].map(str) == '2']
apob["mean"] = apob.loc[:, ["31292", "31282", "31307", "31284", "31279", "31317", "31316", "31299", "31300", "31318", 
                    "31291", "31290", "31278", "31315", "31298", "31306"]].mean(axis=1)
plt.plot(apob["position"], apob["mean"])
plt.title("Coverage APOB")
plt.xticks(rotation=90)
plt.show()
# Out:
# /home/ugdg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
plt.figure()
lipi = df.loc[df['chr'].map(str) == '21']
lipi["mean"] = lipi.loc[:, ["31292", "31282", "31307", "31284", "31279", "31317", "31316", "31299", "31300", "31318", 
                    "31291", "31290", "31278", "31315", "31298", "31306"]].mean(axis=1)
plt.plot(lipi["position"], lipi["mean"])
plt.title("Coverage LIPI")
plt.xticks(rotation=90)
plt.show()
# Out:
# /home/ugdg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
plt.figure()
mttp = df.loc[df['chr'].map(str) == '4']
mttp["mean"] = mttp.loc[:, ["31292", "31282", "31307", "31284", "31279", "31317", "31316", "31299", "31300", "31318", 
                    "31291", "31290", "31278", "31315", "31298", "31306"]].mean(axis=1)
plt.plot(mttp["position"], mttp["mean"])
plt.title("Coverage MTTP")
plt.xticks(rotation=90)
plt.show()
# Out:
# /home/ugdg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
plt.figure()
lpl = df.loc[df['chr'].map(str) == '8']
lpl["mean"] = lpl.loc[:, ["31292", "31282", "31307", "31284", "31279", "31317", "31316", "31299", "31300", "31318", 
                    "31291", "31290", "31278", "31315", "31298", "31306"]].mean(axis=1)
plt.plot(mttp["position"], mttp["mean"])
plt.title("Coverage LPL")
plt.xticks(rotation=90)
plt.show()
# Out:
# /home/ugdg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df = pd.read_csv("/home/ugdg/workspace/coverage_HGUV/pasted_coverages.tsv", sep="\t")
df = df.loc[df['chr'].map(str) == '19']
df.head()
# Out:
#        chr  position  31292  31282  31307  31284  31279  31317  31316  31299  \
# 43188   19  11200028      2     13      6     14      8      3      4      3
# 43189   19  11200029      2     13      6     14      8      3      3      3
# 43190   19  11200030      2     13      6     14      8      3      3      3
# 43191   19  11200031      2     13      6     14      8      3      3      3
# 43192   19  11200032      2     13      6     14      8      3      3      3
#
#        31300  31318  31291  31290  31278  31315  31298  31306  31
# 43188      6      5      6      1      5      7      7      5   3
# 43189      6      5      6      1      5      7      7      5   3
# 43190      6      5      6      1      5      7      7      5   3
# 43191      6      5      6      1      5      7      7      5   3
# 43192      6      5      6      1      5      7      7      5   3

# %%
lrdl = df[df.position < 45408999]
lrdl["position"] = lrdl["chr"].map(str) + "-" + lrdl["position"].map(str)
plt.figure()
lrdl["mean"] = lrdl.loc[:, ["31292", "31282", "31307", "31284", "31279", "31317", "31316", "31299", "31300", "31318", 
                    "31291", "31290", "31278", "31315", "31298", "31306"]].mean(axis=1)
plt.plot(lrdl["position"], lrdl["mean"])
plt.title("Coverage LRDL")
plt.xticks(rotation=90)
plt.show()
# Out:
# /home/ugdg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ugdg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
apoe = df[df.position > 45408999]
apoe = apoe[apoe.position < 45412661]
apoe["position"] = apoe["chr"].map(str) + "-" + apoe["position"].map(str)
plt.figure()
apoe["mean"] = apoe.loc[:, ["31292", "31282", "31307", "31284", "31279", "31317", "31316", "31299", "31300", "31318", 
                    "31291", "31290", "31278", "31315", "31298", "31306"]].mean(axis=1)
plt.plot(apoe["position"], apoe["mean"])
plt.title("Coverage APOE")
plt.xticks(rotation=90)
plt.show()

# %%
apoc2 = df[df.position > 45412661]
apoc2 = apoc2[apoc2.position < 45452825]
apoc2["position"] = apoc2["chr"].map(str) + "-" + apoc2["position"].map(str)
plt.figure()
apoc2["mean"] = apoc2.loc[:, ["31292", "31282", "31307", "31284", "31279", "31317", "31316", "31299", "31300", "31318", 
                    "31291", "31290", "31278", "31315", "31298", "31306"]].mean(axis=1)
plt.plot(apoc2["position"], apoc2["mean"])
plt.title("Coverage APOC2")
plt.xticks(rotation=90)
plt.show()
